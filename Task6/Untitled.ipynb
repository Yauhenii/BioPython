# %% [markdown]
# # Геномная последовательность №1

# %% [raw]
# 1. Genscan

# %% [markdown]
# ![Screen%20Shot%202020-05-24%20at%2016.54.31.png](attachment:Screen%20Shot%202020-05-24%20at%2016.54.31.png)
